# %%
from common_imports import *
# %matplotlib inline
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# # PacMan SmallGrid Generator

# %%
def load_task(path):
    _layout = layout.getLayout(path)
    ghostType = DirectionalGhost
    agents = [ghostType( i+1 ) for i in range(2)]
    display = textDisplay.NullGraphics()
    task = PacmanTask(_layout, agents, display, state_repr='stack')
    return task
task0 = load_task('data/layouts/smallGrid.lay')

task = task

# %%
def expand_tasks(old_tasks, op):
    return sum(map(lambda tk: PacmanTaskShifter.neighbors(tk, [op]), old_tasks), [])

# %%
task_no_ghost = PacmanTaskShifter.neighbors(task, ['del_ghost'])

# %%
task21 = expand_tasks(task_no_ghost, 'del_food')
task21 = expand_tasks(task21, 'move_pacman')
print task21
# Out:
# [%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# % v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# %v%%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ]

# %%
task2 = expand_tasks(task_no_ghost, 'move_pacman')
task3 = expand_tasks([task], 'move_pacman')
tasks = task21 + task2 + task3
random.shuffle(tasks)
print tasks
# Out:
# [%%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.vG  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. G v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. Gv %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# %v%%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: -69.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# % v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ]

# %%
print 'number of tasks', len(tasks)
# Out:
# number of tasks 65

# %%
tasks[1]
# Out:
# %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00

# %%
tasks[30]
# Out:
# %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00

# %% [markdown]
# ### Test Distance / Metric

# %%
PacmanTaskDistance.dist_food(tasks[1], tasks[30])
# Out:
# 2.0

# %% [markdown]
# ## Feature Space

# %%
def feat_dist(task_a, task_b):
    weights = {
        'dist_food': 1,
        'dist_pacman': 1,
        'dist_num_ghost': 1
    }
    dist = 0.
    for key, val in weights.items():
        dist += val * getattr(PacmanTaskDistance, key)(task_a, task_b)
    return dist

# %%
feat_dist(tasks[1], tasks[30])
# Out:
# 6.0

# %% [markdown]
# ## Meta-Feature Extractors / Experts

# %%
def mf_nb(im_mem, curr_task):
    avg_im = 0.
    for (task, im) in im_mem[::-1]:
        if task == curr_task:
            break
        dist = feat_dist(task, curr_task)
        avg_im += np.exp(1.-dist) * im
    return avg_im

mf_exs = [mf_nb]

# %% [markdown]
# ## Learning

# %%
state_shape = task.state_shape

def two_layer(states):
    '''
    two layer neural network with same number of hidden units.
    '''
    state_vecs = states.flatten(2)
    return arch.two_layer(state_vecs, np.prod(task.state_shape), 128, task.num_actions)

def conv_net(states):
    '''
    conv+max-pool layer first followed by a fully-connected layer.
    '''
    conv1 = Conv(state_shape[0], output_dim=32, filter_size=(2,2), pool_size=(2,2), activation='relu')
    h1 = conv1(states)
    h1_dim = int((state_shape[1]-2+1)/2) * int((state_shape[2]-2+1)/2) * 32
    h1 = h1.flatten(2)
    fc1 = FullyConnected(input_dim=h1_dim, output_dim=128, activation='relu')
    h2 = fc1(h1)
    linear_layer = FullyConnected(input_dim=128, output_dim=task.num_actions, activation=None)
    output = linear_layer(h2)
    return (output, {
        'conv1': conv1,
        'fc1': fc1
    })



def conv_net2(states):
    '''
    2 conv + max-pool layers followed by a fully-connected layer.
    '''
    conv1 = Conv(state_shape[0], output_dim=16, filter_size=(2,2), pool_size=(2,2), activation='relu')
    h1 = conv1(states)
    h1_shape = (16, int((state_shape[1]-2+1)/2), int((state_shape[2]-2+1)/2))
    print 'h1_shape', h1_shape
    conv2 = Conv(h1_shape[0], output_dim=32, filter_size=(2,2), pool_size=(2,2), activation='relu')
    h2_shape = (int((h1_shape[1]-2+1)/2), int((h1_shape[2]-2+1)/2), 32)
    print 'h2_shape', h2_shape
    h1 = conv1(states)
    h2 = conv2(h1)
    h2 = h2.flatten(2)
    fc1 = FullyConnected(input_dim=np.prod(h2_shape), output_dim=32, activation='relu')
    h2 = fc1(h2)
    linear_layer = FullyConnected(input_dim=32, output_dim=task.num_actions, activation=None)
    output = linear_layer(h2)
    return (output, {
        'conv1': conv1,
        'conv2': conv2,
        'fc1': fc1
    })

# %%
dqn = DQN(task, arch_func=conv_net, state_type=T.tensor4)

# %%
gamma = 0.9
budget = 20
learner = DeepQlearn(dqn, gamma=gamma, lr=1e-2, memory_size = 500, epsilon=0.3)
def run_task(task, num_iter):
    for it in range(num_iter):
        learner.run(task, num_episodes = 10, tol=1e-4)
        score = reward_stochastic(dqn, task, gamma=gamma, num_trials=10, tol=1e-4, method='eps-greedy', epsilon=0.0)
        scores.append(score)
        total_exps.append(learner.total_exp)
        print 'it', it, 'total exp', learner.total_exp, 'score', scores[-1]
        
train_func = lambda task:  learner.run(task, num_episodes = 10, tol=1e-4, budget=budget)
# eval_func = lambda policy, task: qval_stochastic(policy, task, gamma=gamma, num_trials=10, budget=budget, method='eps-greedy', epsilon=0.)
eval_func = lambda policy, task: reward_stochastic(policy, task, gamma=gamma, num_trials=10, budget=budget, method='eps-greedy', epsilon=0.)
score_func = lambda policy, task: reward_stochastic(policy, task, gamma=gamma, num_trials=10, tol=1e-4, method='eps-greedy', epsilon=0.)

# %%
qval_stochastic(dqn, task0, gamma=gamma, num_trials=10, budget=budget, method='eps-greedy', epsilon=0.)
# Out:
# -209.80508623732007

# %%
reward_stochastic(dqn, task0, gamma=gamma, num_trials=10, budget=budget, method='eps-greedy', epsilon=0.)
# Out:
# -216.16935261841007

# %%
train_func(tasks[0])

# %%
eval_func(dqn, tasks[0])
# Out:
# -4.1163537674500068

# %%
meta = DQCL.DriftExpert(dqn, mf_exs, train_func, eval_func, eta=1/20.)

# %%
def topk(dic, k=5):
    candidates = sorted(dic.keys(), key=lambda key: dic[key], reverse=True)
    return {key: dic[key] for key in candidates[:k]}

# %%
scores = []
exs = []
for it in range(1000):
    meta.run(tasks, num_epochs=1)
    print 'iteration', it
#     print 'count'
#     pprint(topk(meta.task_count))
#     print 'pred'
#     pprint(topk(meta.im_pred))
#     print 'ucb'
#     pprint(topk(meta.im_ucb))
#     print 'meta features'
#     pprint(topk(meta.im_feat))
#     print 'im_mem'
#     pprint(meta.im_mem)
#     pprint(meta.diagnostics)
    for key in ['score after', 'score before', 'task chosen']:
        print key, meta.diagnostics[key]
    task_chosen = meta.diagnostics['task chosen']
    print 'pred', meta.im_feat[task_chosen][str(mf_nb)]
    if (it + 1) % 10 == 0:
        exs.append(learner.total_exp)
        score = score_func(dqn, task0)
        scores.append(score)
        print '=== game play score ===', score
    print '---------------------------------------'
#     clear_output()
# Out:
# iteration 0
# score after 25.7663080986
# score before 39.8293455057
# task chosen %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 290.74222112
# ---------------------------------------
# iteration 1
# score after 46.3818137006
# score before 16.3567954866
# task chosen %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 228.430580216
# ---------------------------------------
# iteration 2
# score after 509.0
# score before 509.0
# task chosen %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
#
# pred 213.346469793
# ---------------------------------------
# iteration 3
# score after 55.6740087306
# score before 46.1335521821
# task chosen %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 201.209334725
# ---------------------------------------
# iteration 4
# score after 83.180569362
# score before 37.3373932445
# task chosen %%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 160.592181795
# ---------------------------------------
# iteration 5
# score after 70.1090328276
# score before 62.2401197757
# task chosen %%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 173.951663444
# ---------------------------------------
# iteration 6
# score after -317.178618793
# score before -270.17772981
# task chosen %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
#
# pred 141.092822054
# ---------------------------------------
# iteration 7
# score after 59.902445354
# score before 25.1934408738
# task chosen %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
#
# pred 121.680559404
# ---------------------------------------
# iteration 8
# score after 104.029965822
# score before 77.8620486584
# task chosen %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 104.564726384
# ---------------------------------------
# iteration 9
# score after 131.962012563
# score before 66.7980699408
# task chosen %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 113.353258112
# === game play score === -200.223460099
# ---------------------------------------
# iteration 10
# score after 117.88243803
# score before 131.962012563
# task chosen %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 171.624752066
# ---------------------------------------
# iteration 11
# score after 121.410781213
# score before 154.647090102
# task chosen %%%%%%%
# %     %
# % %%%v%
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 154.295660809
# ---------------------------------------
# iteration 12
# score after 61.2213227801
# score before 60.4164104561
# task chosen %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
#
# pred 132.412057541
# ---------------------------------------
# iteration 13
# score after 54.2943663858
# score before 81.5221095358
# task chosen %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 120.931050139
# ---------------------------------------
# iteration 14
# score after 66.3795786323
# score before 53.6647933301
# task chosen %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
#
# pred 111.628067729
# ---------------------------------------
# iteration 15
# score after 37.5282208807
# score before 50.3248726451
# task chosen %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
#
# pred 113.348826799
# ---------------------------------------
# iteration 16
# score after 58.0442453417
# score before 50.120613355
# task chosen %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
#
# pred 102.756402104
# ---------------------------------------
# iteration 17
# score after 66.1070888867
# score before 82.4926436662
# task chosen %%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 102.86981793
# ---------------------------------------
# iteration 18
# score after 457.1
# score before 457.1
# task chosen %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
#
# pred 93.3161112615
# ---------------------------------------
# iteration 19
# score after 230.993168152
# score before 214.766838532
# task chosen %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
#
# pred 86.1374759845
# === game play score === -222.526660665
# ---------------------------------------
# iteration 20
# score after 196.104642042
# score before 190.753591853
# task chosen %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
#
# pred 82.6100188485
# ---------------------------------------
# iteration 21
# score after 113.149017392
# score before 122.335771366
# task chosen %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 76.5083009519
# ---------------------------------------
# iteration 22
# score after -501.0
# score before -501.0
# task chosen %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. Gv %
# %%%%%%%
# Score: 0.00
#
# pred 75.186216346
# ---------------------------------------
# iteration 23
# score after 268.688659062
# score before 202.18269185
# task chosen %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
#
# pred 72.6411858923
# ---------------------------------------
# iteration 24
# score after 219.119581108
# score before 294.872230429
# task chosen %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
#
# pred 101.992080235
# ---------------------------------------
# iteration 25
# score after 44.788039387
# score before 70.0268994709
# task chosen %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 65.4214000571
# ---------------------------------------
# iteration 26
# score after 127.118455723
# score before 158.056381558
# task chosen %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
#
# pred 62.6540609438
# ---------------------------------------
# iteration 27
# score after 14.6788214713
# score before 36.6962830688
# task chosen %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 59.6251233291
# ---------------------------------------
# iteration 28
# score after 51.6457814172
# score before 29.8213089187
# task chosen %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 58.2900938836
# ---------------------------------------
# iteration 29
# score after 50.1779619113
# score before 49.1906899978
# task chosen %%%%%%%
# %     %
# %v%%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
#
# pred 62.3312011477
# === game play score === -211.707320838
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-01515638284b> in <module>()
#       2 exs = []
#       3 for it in range(1000):
# ----> 4     meta.run(tasks, num_epochs=1)
#       5     print 'iteration', it
#       6 #     print 'count'
#
# /Users/tianlins/Project/curriculum/src/rl/pyrl/algorithms/drift_expert.pyc in run(self, tasks, num_epochs)
#      65                     pred = 0.
#      66                     for (ei, extractor) in enumerate(self.meta_feature_exs):
# ---> 67                         val = extractor(self.im_mem, task)
#      68                         self.im_feat[task][str(extractor)] = val
#      69                         pred += val * self.meta_weights[ei]         # expected improvement prediction.
#
# <ipython-input-13-3c6cb81fed8f> in mf_nb(im_mem, curr_task)
#       4         if task == curr_task:
#       5             break
# ----> 6         dist = feat_dist(task, curr_task)
#       7         avg_im += np.exp(1.-dist) * im
#       8     return avg_im
#
# <ipython-input-11-c3beb00f61f8> in feat_dist(task_a, task_b)
#       7     dist = 0.
#       8     for key, val in weights.items():
# ----> 9         dist += val * getattr(PacmanTaskDistance, key)(task_a, task_b)
#      10     return dist
#
# /Users/tianlins/Project/curriculum/src/rl/pyrl/tasks/pacman/game_mdp.pyc in dist_food(task_a, task_b)
#     375     def dist_food(task_a, task_b):
#     376         get_food = lambda task: task.game.state.data.array()['food']
# --> 377         return float(np.sum(np.abs(get_food(task_a) - get_food(task_b))))
#     378
#     379     @staticmethod
#
# /Users/tianlins/Project/curriculum/src/rl/pyrl/tasks/pacman/game_mdp.pyc in <lambda>(task)
#     374     @staticmethod
#     375     def dist_food(task_a, task_b):
# --> 376         get_food = lambda task: task.game.state.data.array()['food']
#     377         return float(np.sum(np.abs(get_food(task_a) - get_food(task_b))))
#     378
#
# /Users/tianlins/Project/curriculum/src/rl/pyrl/tasks/pacman/game.pyc in array(self)
#     470         return {
#     471             'food': np.array(self.food.data, dtype=float),
# --> 472             'wall': np.array(self.layout.walls.data, dtype=float),
#     473             'pacman': pacman_array,
#     474             'ghosts': np.array(agent_array_list)
#
# KeyboardInterrupt:

# %%
it
# Out:
# 58

# %%
task = tasks[50]
# task = task0
task.reset()
while not task.is_end():
    action = dqn.get_action(task.curr_state, method='eps-greedy', epsilon=0., valid_actions=task.valid_actions)
#     action = dqn.get_action(task.curr_state, method='softmax', temperature=1, valid_actions=task.valid_actions)
    task.step(action)
    print task
    print task.valid_actions
    sys.stdout.flush()
    time.sleep(.5)
    clear_output()

# %%
exs
# Out:
# [6232, 6708, 7168]

# %%
scores
# Out:
# [-200.22346009900005, -222.52666066534007, -211.70732083831007]

# %%
plot(exs, scores)
