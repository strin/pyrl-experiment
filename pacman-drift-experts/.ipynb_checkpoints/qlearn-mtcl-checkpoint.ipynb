# %%
from common_imports import *
# %matplotlib inline
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# # PacMan SmallGrid Generator

# %%
def load_task(path):
    _layout = layout.getLayout(path)
    ghostType = DirectionalGhost
    agents = [ghostType( i+1 ) for i in range(2)]
    display = textDisplay.NullGraphics()
    task = PacmanTask(_layout, agents, display, state_repr='stack')
    return task
task = load_task('data/layouts/smallGrid.lay')

# %%
def expand_tasks(old_tasks, op):
    return sum(map(lambda tk: PacmanTaskShifter.neighbors(tk, [op]), old_tasks), [])

# %%
task_no_ghost = PacmanTaskShifter.neighbors(task, ['del_ghost'])

# %%
task21 = expand_tasks(task_no_ghost, 'del_food')
task21 = expand_tasks(task21, 'move_pacman')
print task21
# Out:
# [%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# % v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# %v%%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ]

# %%
task2 = expand_tasks(task_no_ghost, 'move_pacman')
task3 = expand_tasks([task], 'move_pacman')
tasks = task21 + task2 + task3
print tasks
# Out:
# [%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# % v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# %v%%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# %v%.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# %v%%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %v    %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.vG  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. Gv %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. G v%
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , %%%%%%%
# %    v%
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ]

# %%
print 'number of tasks', len(tasks)
# Out:
# number of tasks 65

# %%
tasks[1]
# Out:
# %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00

# %%
tasks[30]
# Out:
# %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00

# %% [markdown]
# ### Test Distance / Metric

# %%
PacmanTaskDistance.dist_food(tasks[1], tasks[30])
# Out:
# 2.0

# %% [markdown]
# ## Feature Space

# %%
def feat_dist(task_a, task_b):
    weights = {
        'dist_food': 1,
        'dist_pacman': 1,
        'dist_num_ghost': 1
    }
    dist = 0.
    for key, val in weights.items():
        dist += val * getattr(PacmanTaskDistance, key)(task_a, task_b)
    return dist

# %%
feat_dist(tasks[1], tasks[30])
# Out:
# 6.0

# %% [markdown]
# ## Meta-Feature Extractors / Experts

# %%
def mf_nb(im_mem, curr_task):
    avg_im = 0.
    for (task, im) in im_mem[::-1]:
        if task == curr_task:
            break
        dist = feat_dist(task, curr_task)
        avg_im += np.exp(1.-dist) * im
    return avg_im

mf_exs = [mf_nb]

# %% [markdown]
# ## Learning

# %%
state_shape = task.state_shape

def two_layer(states):
    '''
    two layer neural network with same number of hidden units.
    '''
    state_vecs = states.flatten(2)
    return arch.two_layer(state_vecs, np.prod(task.state_shape), 128, task.num_actions)

def conv_net(states):
    '''
    conv+max-pool layer first followed by a fully-connected layer.
    '''
    conv1 = Conv(state_shape[0], output_dim=32, filter_size=(2,2), pool_size=(2,2), activation='relu')
    h1 = conv1(states)
    h1_dim = int((state_shape[1]-2+1)/2) * int((state_shape[2]-2+1)/2) * 32
    h1 = h1.flatten(2)
    fc1 = FullyConnected(input_dim=h1_dim, output_dim=128, activation='relu')
    h2 = fc1(h1)
    linear_layer = FullyConnected(input_dim=128, output_dim=task.num_actions, activation=None)
    output = linear_layer(h2)
    return (output, {
        'conv1': conv1,
        'fc1': fc1
    })



def conv_net2(states):
    '''
    2 conv + max-pool layers followed by a fully-connected layer.
    '''
    conv1 = Conv(state_shape[0], output_dim=16, filter_size=(2,2), pool_size=(2,2), activation='relu')
    h1 = conv1(states)
    h1_shape = (16, int((state_shape[1]-2+1)/2), int((state_shape[2]-2+1)/2))
    print 'h1_shape', h1_shape
    conv2 = Conv(h1_shape[0], output_dim=32, filter_size=(2,2), pool_size=(2,2), activation='relu')
    h2_shape = (int((h1_shape[1]-2+1)/2), int((h1_shape[2]-2+1)/2), 32)
    print 'h2_shape', h2_shape
    h1 = conv1(states)
    h2 = conv2(h1)
    h2 = h2.flatten(2)
    fc1 = FullyConnected(input_dim=np.prod(h2_shape), output_dim=32, activation='relu')
    h2 = fc1(h2)
    linear_layer = FullyConnected(input_dim=32, output_dim=task.num_actions, activation=None)
    output = linear_layer(h2)
    return (output, {
        'conv1': conv1,
        'conv2': conv2,
        'fc1': fc1
    })

# %%
dqn = DQN(task, arch_func=conv_net, state_type=T.tensor4)

# %%
gamma = 0.9
budget = 20
learner = DeepQlearnMT(dqn, gamma=gamma, lr=1e-2, memory_size = 100, epsilon=0.3)
def run_task(task, num_iter):
    for it in range(num_iter):
        learner.run(task, num_episodes = 10, tol=1e-4)
        score = reward_stochastic(dqn, task, gamma=gamma, num_trials=10, tol=1e-4, method='eps-greedy', epsilon=0.0)
        scores.append(score)
        total_exps.append(learner.total_exp)
        print 'it', it, 'total exp', learner.total_exp, 'score', scores[-1]
        
train_func = lambda task:  learner.run(task, num_episodes = 10, tol=1e-4, budget=budget)
eval_func = lambda policy, task: qval_stochastic(policy, task, gamma=gamma, num_trials=10, method='eps-greedy', epsilon=0.)
score_func = lambda policy, task: reward_stochastic(policy, task, gamma=gamma, num_trials=10, tol=1e-4, method='eps-greedy', epsilon=0.)

# %%
train_func(tasks[0])

# %%
eval_func(dqn, tasks[0])
# Out:
# -9.7368718844925173

# %%
meta = DQCL.DriftExpert(dqn, mf_exs, train_func, eval_func, eta=1/20.)

# %%
def topk(dic, k=5):
    candidates = sorted(dic.keys(), key=lambda key: dic[key], reverse=True)
    return {key: dic[key] for key in candidates[:k]}

# %%
for it in range(1000):
    meta.run(tasks, num_epochs=1)
    print 'iteration', it
#     print 'count'
#     pprint(topk(meta.task_count))
#     print 'pred'
#     pprint(topk(meta.im_pred))
#     print 'ucb'
#     pprint(topk(meta.im_ucb))
#     print 'meta features'
#     pprint(topk(meta.im_feat))
    print 'im_mem'
    pprint(meta.im_mem)
    pprint(meta.diagnostics)
    if it + 1 % 10 == 0:
        print '=== game play score ===', score_func(dqn, task)
    print '---------------------------------------'
#     clear_output()
# Out:
# iteration 0
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  >  %
# %%%%%%%
# Score: -20.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  >  %
# %%%%%%%
# Score: -20.00
# : -9.9823629611315567,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 265.81787900000012,
#  'score before': 23.606625670615156,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 1
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  >  %
# %%%%%%%
# Score: -20.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  >  %
# %%%%%%%
# Score: -20.00
# : -9.9823629611315567,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 200.07123379100003,
#  'score before': 21.508939713547544,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 2
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  >  %
# %%%%%%%
# Score: -20.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  >  %
# %%%%%%%
# Score: -20.00
# : -9.9823629611315567,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 179.06411041190003,
#  'score before': 179.06411041190003,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 3
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 238.23609110000007,
#  'score before': 238.23609110000007,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 4
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 213.41248199000012,
#  'score before': 213.41248199000012,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 5
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 296.46431000000013,
#  'score before': 296.46431000000013,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 6
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# : 368.35100000000006,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 368.35100000000006,
#  'score before': 368.35100000000006,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 7
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# : 368.35100000000006,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 410.38999999999999,
#  'score before': 410.38999999999999,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 8
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# : 368.35100000000006,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 457.10000000000002,
#  'score before': 457.10000000000002,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 9
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# : 368.35100000000006,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 410.38999999999999,
#  'score before': 410.38999999999999,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 10
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# ,
#   44.348371578100085)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# : 368.35100000000006,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 223.41248199000012,
#  'score before': 179.06411041190003,
#  'task chosen': %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 11
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# ,
#   44.348371578100085),
#  (%%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   200.2634276688735)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# : 368.35100000000006,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
# ...
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# % v   %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. Gv %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   83.785764037230095),
#  (%%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -8.9648641306900814),
#  (%%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   26.18726993315228),
#  (%%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %  v  %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   175.6304521539052),
#  (%%%%%%%
# % v   %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# % v   %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 330.51589999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# : 368.35100000000006,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# % v   %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 330.51589999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %  v  %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 191.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 22.050415793964135,
#                   %%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 127.82773649027516,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 90.476419901410608,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# : 160.15769937071011,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. Gv %
# %%%%%%%
# Score: 0.00
# : -501.0,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 296.46431000000013,
#  'score before': 296.46431000000013,
#  'task chosen': %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# iteration 28
# im_mem
# [(%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.24549107663903946),
#  (%%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -0.025120737391654657),
#  (%%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -49.537493348713866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -166.2509113535541),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   101.82072390210004),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -62.104073710382892),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   112.63857946347866),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   -40.914956003691543),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   25.242653155137276),
#  (%%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# ,
#   108.5584464902232),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# ,
#   -13.210531958309488),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   149.00122831885838),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   76.831552556361032),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# ,
#   497.67094083363872),
#  (%%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -16.199374665516078),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# ,
#   242.21125332938496),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# ,
#   178.56229407745249),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# ,
#   44.348371578100085),
#  (%%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   200.2634276688735),
#  (%%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# % v   %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. Gv %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   83.785764037230095),
#  (%%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   -8.9648641306900814),
#  (%%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   26.18726993315228),
#  (%%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %  v  %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# ,
#   175.6304521539052),
#  (%%%%%%%
# % v   %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# , 0.0),
#  (%%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# , 0.0)]
# {'latest score': {%%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %v    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# %v%%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 213.41248199000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# % v   %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %  v  %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %   v %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 330.51589999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %    v%
# %%%%%%%
# Score: 0.00
# : 368.35100000000006,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %     %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.v   %
# %%%%%%%
# Score: 0.00
# : 509.0,
#                   %%%%%%%
# % v   %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 330.51589999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 457.10000000000002,
#                   %%%%%%%
# %     %
# % %%% %
# % %v  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 238.23609110000007,
#                   %%%%%%%
# %  v  %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 191.07123379100003,
#                   %%%%%%%
# %     %
# % %%% %
# % %   %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 410.38999999999999,
#                   %%%%%%%
# %     %
# % %%% %
# % % v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 265.81787900000012,
#                   %%%%%%%
# %     %
# % %%% %
# % %  v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 296.46431000000013,
#                   %%%%%%%
# %    v%
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : -9.9780860547808743,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. v  %
# %%%%%%%
# Score: 0.00
# : 200.07123379100003,
#                   %%%%%%%
# %  v  %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 127.82773649027516,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.  v %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %.v %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 223.41248199000012,
#                   %%%%%%%
# %   v %
# % %%% %
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 90.476419901410608,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %.   v%
# %%%%%%%
# Score: 0.00
# : 160.15769937071011,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%%v%
# %.    %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 17.936813553187566,
#                   %%%%%%%
# %     %
# % %%%v%
# % %.  %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# : 179.06411041190003,
#                   %%%%%%%
# % v   %
# % %%% %
# % %.  %
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -332.14510000000013,
#                   %%%%%%%
# %     %
# % %%% %
# % %.  %
# % %%% %
# %. Gv %
# %%%%%%%
# Score: 0.00
# : -501.0,
#                   %%%%%%%
# %   G %
# % %%% %
# % %   %
# % %%%^%
# %.    %
# %%%%%%%
# Score: 1.00
# : -24.905103721833868,
#                   %%%%%%%
# %     %
# % %%% %
# % %. v%
# % %%% %
# %. G  %
# %%%%%%%
# Score: 0.00
# : -138.66772409023375},
#  'score after': 265.81787900000012,
#  'score before': 265.81787900000012,
#  'task chosen': %%%%%%%
# %   v %
# % %%% %
# % %   %
# % %%% %
# %.    %
# %%%%%%%
# Score: 0.00
# }
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-a9f3cb98e884> in <module>()
#       1 for it in range(1000):
# ----> 2     meta.run(tasks, num_epochs=1)
#       3     print 'iteration', it
#       4 #     print 'count'
#       5 #     pprint(topk(meta.task_count))
#
# /Users/tianlins/Project/curriculum/src/rl/pyrl/algorithms/drift_expert.pyc in run(self, tasks, num_epochs)
#      81                 # train task, and estimate improvement.
#      82                 score_before = self.eval_func(self.policy, task_chosen)
# ---> 83                 self.train_func(task_chosen)
#      84                 score_after = self.eval_func(self.policy, task_chosen)
#      85                 im = score_after - score_before
#
# <ipython-input-17-05d1f7a00a57> in <lambda>(task)
#      10         print 'it', it, 'total exp', learner.total_exp, 'score', scores[-1]
#      11
# ---> 12 train_func = lambda task:  learner.run(task, num_episodes = 10, tol=1e-4, budget=budget)
#      13 eval_func = lambda policy, task: qval_stochastic(policy, task, gamma=gamma, num_trials=10, method='eps-greedy', epsilon=0.)
#
# /Users/tianlins/Project/curriculum/src/rl/pyrl/algorithms/multitask.pyc in run(self, task, num_episodes, tol, budget)
#     443                     break
#     444                 else:
# --> 445                     self._learn(task, next_state, reward, task.valid_actions)
#     446                     curr_state = next_state
#     447
#
# /Users/tianlins/Project/curriculum/src/rl/pyrl/algorithms/multitask.pyc in _learn(self, task, next_state, reward, next_valid_actions)
#     399         self._add_to_experience(task, self.last_state, self.last_action,
#     400                                 next_state, reward, next_valid_actions)
# --> 401         self._update_net(task)
#     402
#     403     def _end_episode(self, task, reward):
#
# /Users/tianlins/Project/curriculum/src/rl/pyrl/algorithms/multitask.pyc in _update_net(self, task)
#     390             #print 'actions', actions
#     391             #for it in range(10):
# --> 392             error = self.bprop(states, actions, targets.flatten())
#     393             #    print 'error', error
#     394
#
# /Library/Python/2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
it
# Out:
# 29

# %%
task = tasks[39]
task.reset()
while not task.is_end():
    action = dqn.get_action(task.curr_state, method='eps-greedy', epsilon=0., valid_actions=task.valid_actions)
#     action = dqn.get_action(task.curr_state, method='softmax', temperature=1, valid_actions=task.valid_actions)
    task.step(action)
    print task
    print task.valid_actions
    sys.stdout.flush()
    time.sleep(.5)
    clear_output()
